# %% [markdown]
# ### Capstone project notebook

# %%
import pandas as pd
import geopandas as gpd
import requests
import matplotlib.pyplot as plt
import folium 

from geopy.geocoders import Nominatim 
    
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = 'VMX2TMOEWR3CY5OJE4IAVQ5VTUIZSWBOSBEPMH3BYE24JFDA' # your Foursquare ID
CLIENT_SECRET = 'VSOJEBUALJNGTNMIRUKLAYYSJCZG5LHS2QIEF0YJO435HEL4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 500

# %% [markdown]
# # Acquiring Hospital Data

# %%
search_query = 'Hospital'
radius = 50000
print(search_query + ' .... OK!')

latitude = 51.5074
longitude = 0.1277
# Out:
# Hospital .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc8966d2aa0530e5aa640b9'},
#  'response': {'venues': [{'id': '4b4e1c8af964a5209ce126e3',
#     'name': "Guy's Hospital",
#     'location': {'address': 'Great Maze Pond',
#      'crossStreet': 'St. Thomas St',
#      'lat': 51.50352551239466,
#      'lng': -0.0867319107055664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50352551239466,
#        'lng': -0.0867319107055664}],
#      'distance': 14864,
#      'postalCode': 'SE1 9RT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Great Maze Pond (St. Thomas St)',
#       'London',
#       'Greater London',
#       'SE1 9RT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bfe353af7c82d7f8a438f04',
#     'name': 'Queen Elizabeth Hospital',
#     'location': {'address': 'Stadium Rd.',
#      'lat': 51.478860897657334,
#      'lng': 0.05071712801203341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.478860897657334,
#        'lng': 0.05071712801203341}],
#      'distance': 6209,
#      'postalCode': 'SE18 4QH',
#      'cc': 'GB',
#      'city': 'Greenwich',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Stadium Rd.',
#       'Greenwich',
#       'Greater London',
#       'SE18 4QH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bf3a32b706e20a1976ca898',
#     'name': "King's College Hospital",
#     'location': {'address': 'Denmark Hill',
#      'lat': 51.46814989580254,
#      'lng': -0.09301624939952001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.46814989580254,
#        'lng': -0.09301624939952001}],
#      'distance': 15910,
#      'postalCode': 'SE5 9RS',
#      'cc': 'GB',
#      'city': 'Camberwell',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Denmark Hill',
#       'Camberwell',
#       'Greater London',
#       'SE5 9RS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '600424239'},
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ac518f6f964a5205eaf20e3',
#     'name': "St Thomas' Hospital",
#     'location': {'address': 'Westminster Bridge Rd',
#      'lat': 51.49971047720161,
#      'lng': -0.11890384052741654,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49971047720161,
#        'lng': -0.11890384052741654}],
#      'distance': 17109,
#      'postalCode': 'SE1 7EH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Westminster Bridge Rd',
#       'London',
#       'Greater London',
#       'SE1 7EH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4be47840910020a1e0c2d114',
#     'name': "Queen Mary's Hospital",
#     'location': {'address': 'Frognal Ave',
#      'lat': 51.41956136232628,
#      'lng': 0.10154861220226892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.41956136232628,
#        'lng': 0.10154861220226892}],
#      'distance': 9944,
#      'postalCode': 'DA14 6LT',
#      'cc': 'GB',
#      'neighborhood': 'Sidcup, London, Greater London',
#      'city': 'Sidcup',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Frognal Ave',
#       'Sidcup',
#       'Greater London',
#       'DA14 6LT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b8baecdf964a520d6a632e3',
#     'name': "Queen's Hospital",
#     'location': {'address': 'Rom Valley Way',
#      'lat': 51.568022253534416,
#      'lng': 0.1802357991197366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.568022253534416,
#        'lng': 0.1802357991197366}],
#      'distance': 7666,
#      'postalCode': 'RM7 0AG',
#      'cc': 'GB',
#      'neighborhood': 'Rush Green',
#      'city': 'Romford',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rom Valley Way',
#       'Romford',
#       'Greater London',
#       'RM7 0AG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ba73850f964a520768639e3',
#     'name': 'Newham General  Hospital',
#     'location': {'address': 'Glen Road',
#      'lat': 51.52313854563254,
#      'lng': 0.03430141473703306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52313854563254,
#        'lng': 0.03430141473703306}],
#      'distance': 6703,
#      'postalCode': 'E13 8SL',
#      'cc': 'GB',
#      'city': 'Newham',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Glen Road',
#       'Newham',
#       'Greater London',
#       'E13 8SL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bcecb59fb84c9b6be4d243e',
#     'name': "St Bartholomew's Hospital",
#     'location': {'address': 'W Smithfield',
#      'crossStreet': 'West Smithfield',
#      'lat': 51.517863114858024,
#      'lng': -0.09960651397705078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.517863114858024,
#        'lng': -0.09960651397705078}],
#      'distance': 15790,
#      'postalCode': 'EC1A 7BE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['W Smithfield (West Smithfield)',
#       'London',
#       'Greater London',
#       'EC1A 7BE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ba8e760f964a520aff839e3',
#     'name': 'Whipps Cross University Hospital',
#     'location': {'address': 'Whipps Cross Rd',
#      'crossStreet': 'James Ln',
#      'lat': 51.578061079698024,
#      'lng': 0.002804169813921207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.578061079698024,
#        'lng': 0.002804169813921207}],
#      'distance': 11689,
#      'postalCode': 'E11 1NR',
#      'cc': 'GB',
#      'city': 'Leytonstone',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Whipps Cross Rd (James Ln)',
#       'Leytonstone',
#       'Greater London',
#       'E11 1NR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b2a6f99f964a5201da924e3',
#     'name': 'The Hospital of St John & St Elizabeth',
#     'location': {'address': '60 Grove End Rd',
#      'lat': 51.53294945072234,
#      'lng': -0.17464498540156323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53294945072234,
#        'lng': -0.17464498540156323}],
#      'distance': 21134,
#      'postalCode': 'NW8 9NH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['60 Grove End Rd',
#       'London',
#       'Greater London',
#       'NW8 9NH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '67771526'},
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b0c0320f964a520af3523e3',
#     'name': 'Royal London Hospital',
#     'location': {'address': 'Whitechapel Rd',
#      'lat': 51.51819808660023,
#      'lng': -0.05918151371201946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51819808660023,
#        'lng': -0.05918151371201946}],
#      'distance': 13002,
#      'postalCode': 'E1 1BB',
#      'cc': 'GB',
#      'city': 'Whitechapel',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Whitechapel Rd',
#       'Whitechapel',
#       'Greater London',
#       'E1 1BB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4dc1bd58e4cd9161c6389a18',
#     'name': 'Barking Hospital',
#     'location': {'address': 'Upney Ln.',
#      'lat': 51.53901475629076,
#      'lng': 0.09875167624796105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53901475629076,
#        'lng': 0.09875167624796105}],
#      'distance': 4050,
#      'postalCode': 'IG11 9PH',
#      'cc': 'GB',
#      'city': 'Barking',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Upney Ln.',
#       'Barking',
#       'Greater London',
#       'IG11 9PH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bfb839cab180f479befb3ce',
#     'name': 'University College Hospital',
#     'location': {'address': '235 Euston Road',
#      'crossStreet': 'Gower St',
#      'lat': 51.525004422546154,
#      'lng': -0.1363386165036446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.525004422546154,
#        'lng': -0.1363386165036446}],
#      'distance': 18395,
#      'postalCode': 'NW1 2BU',
#      'cc': 'GB',
#      'city': 'Camden Town',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['235 Euston Road (Gower St)',
#       'Camden Town',
#       'Greater London',
#       'NW1 2BU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ac518f6f964a5205baf20e3',
#     'name': 'Homerton University Hospital',
#     'location': {'address': 'Homerton Row',
#      'lat': 51.5501340887911,
#      'lng': -0.045918103615833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5501340887911,
#        'lng': -0.045918103615833}],
#      'distance': 12930,
#      'postalCode': 'E9 6SR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Homerton Row',
#       'Homerton',
#       'Greater London',
#       'E9 6SR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b601d5df964a52048d629e3',
#     'name': 'The Royal Marsden Hospital',
#     'location': {'address': '203 Fulham Rd',
#      'lat': 51.49056863892379,
#      'lng': -0.17357427254782193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49056863892379,
#        'lng': -0.17357427254782193}],
#      'distance': 20961,
#      'postalCode': 'SW3 6JJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['203 Fulham Rd',
#       'London',
#       'Greater London',
#       'SW3 6JJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b3f291df964a5205aa425e3',
#     'name': 'BMI The Blackheath Hospital',
#     'location': {'address': '40/42 Lee Terrace',
#      'lat': 51.46555947792495,
#      'lng': 0.008526106156520155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.46555947792495,
#        'lng': 0.008526106156520155}],
#      'distance': 9483,
#      'postalCode': 'SE3 9UD',
#      'cc': 'GB',
#      'city': 'Blackheath',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40/42 Lee Terrace',
#       'Blackheath',
#       'Greater London',
#       'SE3 9UD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bfcc92b2b83b713ee92a998',
#     'name': "St George's Hospital",
#     'location': {'address': 'Blackshaw Rd',
#      'lat': 51.42664125549244,
#      'lng': -0.17449378967285156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.42664125549244,
#        'lng': -0.17449378967285156}],
#      'distance': 22803,
#      'postalCode': 'SW17 0QT',
#      'cc': 'GB',
#      'city': 'Tooting',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Blackshaw Rd',
#       'Tooting',
#       'Greater London',
#       'SW17 0QT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4edfd6bde5faee9992d59e27',
#     'name': 'The Whittington Hospital',
#     'location': {'address': 'Magdala Ave',
#      'crossStreet': 'at Highgate Hill',
#      'lat': 51.56638482190306,
#      'lng': -0.138475485409035,
#      'distance': 19565,
#      'postalCode': 'N19 5NF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Magdala Ave (at Highgate Hill)',
#       'London',
#       'Greater London',
#       'N19 5NF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b52fb99f964a520f08b27e3',
#     'name': 'Chelsea and Westminster Hospital',
#     'location': {'address': '369 Fulham Rd',
#      'lat': 51.48483069275318,
#      'lng': -0.1822750889856993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48483069275318,
#        'lng': -0.1822750889856993}],
#      'distance': 21628,
#      'postalCode': 'SW10 9NH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['369 Fulham Rd',
#       'London',
#       'Greater London',
#       'SW10 9NH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '151881904'},
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4d50ffe79ffc236ac2961ea7',
#     'name': 'Spire Roding Hospital',
#     'location': {'address': 'Roding Lane South, Woodford, Redbridge',
#      'lat': 51.58701894367303,
#      'lng': 0.0427473708987236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.58701894367303,
#        'lng': 0.0427473708987236}],
#      'distance': 10636,
#      'postalCode': 'IG4 5PZ',
#      'cc': 'GB',
#      'city': 'Essex',
#      'state': 'Essex',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Roding Lane South, Woodford, Redbridge',
#       'Essex',
#       'IG4 5PZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4f71effae4b090ee3efc5873',
#     'name': 'H2 Queen Elizabeth Hospital Bus Stop',
#     'location': {'lat': 51.47860336303711,
#      'lng': 0.05231655016541481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.47860336303711,
#        'lng': 0.05231655016541481}],
#      'distance': 6129,
#      'cc': 'GB',
#      'neighborhood': 'Greenwich',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bfa440ab182c9b6fe137a5a',
#     'name': 'University Hospital Lewisham',
#     'location': {'address': 'Lewisham High St',
#      'lat': 51.453525834433925,
#      'lng': -0.017441452860126747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.453525834433925,
#        'lng': -0.017441452860126747}],
#      'distance': 11713,
#      'postalCode': 'SE13 6LH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Lewisham High St',
#       'Lewisham',
#       'Greater London',
#       'SE13 6LH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b20d3cef964a520cf3424e3',
#     'name': 'Moorfields Eye Hospital',
#     'location': {'address': '162 City Rd',
#      'lat': 51.52780806764324,
#      'lng': -0.08999260062354716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52780806764324,
#        'lng': -0.08999260062354716}],
#      'distance': 15249,
#      'postalCode': 'EC1V 2PD',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['162 City Rd',
#       'London',
#       'Greater London',
#       'EC1V 2PD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b5738d5f964a520c82b28e3',
#     'name': 'London Bridge Hospital',
#     'location': {'address': '27 Tooley St',
#      'lat': 51.50585455769581,
#      'lng': -0.0862311461101383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50585455769581,
#        'lng': -0.0862311461101383}],
#      'distance': 14823,
#      'postalCode': 'SE1 2PR',
#      'cc': 'GB',
#      'neighborhood': 'Riverside',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['27 Tooley St',
#       'London',
#       'Greater London',
#       'SE1 2PR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bd17bec046076b0a0db7171',
#     'name': 'Princess Royal University Hospital',
#     'location': {'address': 'Farnborough Common',
#      'lat': 51.3660999393207,
#      'lng': 0.058405692560894486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.3660999393207,
#        'lng': 0.058405692560894486}],
#      'distance': 16447,
#      'postalCode': 'BR6 8ND',
#      'cc': 'GB',
#      'city': 'Orpington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Farnborough Common',
#       'Orpington',
#       'Greater London',
#       'BR6 8ND',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4baaa4b0f964a520397c3ae3',
#     'name': 'North Middlesex University Hospital',
#     'location': {'address': 'Sterling Way',
#      'lat': 51.613006787849216,
#      'lng': -0.07477998733520508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.613006787849216,
#        'lng': -0.07477998733520508}],
#      'distance': 18291,
#      'postalCode': 'N18 1QX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Sterling Way',
#       'London',
#       'Greater London',
#       'N18 1QX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '602732064'},
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4d490dcf9544a0939e5b24e7',
#     'name': 'Wanstead Hospital',
#     'location': {'lat': 51.58401838541159,
#      'lng': 0.02763998474383725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.58401838541159,
#        'lng': 0.02763998474383725}],
#      'distance': 10987,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '540ec659498e234758131198',
#     'name': 'Homerton University Hospital Physiotherapy',
#     'location': {'lat': 51.550142570891005,
#      'lng': -0.04594889398742459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.550142570891005,
#        'lng': -0.04594889398742459}],
#      'distance': 12932,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4af',
#       'name': 'Physical Therapist',
#       'pluralName': 'Physical Therapists',
#       'shortName': 'Physical Therapist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b30dffbf964a52064fc24e3',
#     'name': 'BMI The London Independent Hospital',
#     'location': {'address': '1 Beaumont Sq',
#      'lat': 51.52053479139095,
#      'lng': -0.046396127747227435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52053479139095,
#        'lng': -0.046396127747227435}],
#      'distance': 12149,
#      'postalCode': 'E1 4NL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Beaumont Sq',
#       'London',
#       'Greater London',
#       'E1 4NL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4befec5fd4e4d13a32aa15a7',
#     'name': 'Darent Valley Hospital',
#     'location': {'address': 'Darenth Wood Rd',
#      'lat': 51.43541920044024,
#      'lng': 0.25834278458625937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.43541920044024,
#        'lng': 0.25834278458625937}],
#      'distance': 12094,
#      'postalCode': 'DA2 8DA',
#      'cc': 'GB',
#      'city': 'Dartford',
#      'state': 'Kent',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Darenth Wood Rd',
#       'Dartford',
#       'Kent',
#       'DA2 8DA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bf63d614d5f20a1260099fe',
#     'name': 'Springfield University Hospital',
#     'location': {'address': '61 Glenburnie Rd',
#      'lat': 51.43663965372439,
#      'lng': -0.1710391044616699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.43663965372439,
#        'lng': -0.1710391044616699}],
#      'distance': 22161,
#      'postalCode': 'SW17 7DJ',
#      'cc': 'GB',
#      'city': 'Tooting',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['61 Glenburnie Rd',
#       'Tooting',
#       'Greater London',
#       'SW17 7DJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4dfdcb357d8b305080196b32',
#     'name': 'Trinity Hospital',
#     'location': {'address': 'Old Woolwich Road',
#      'lat': 51.48521332154809,
#      'lng': -0.0029037213392310484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48521332154809,
#        'lng': -0.0029037213392310484}],
#      'distance': 9382,
#      'postalCode': 'SE10 9AS',
#      'cc': 'GB',
#      'city': 'Greenwich',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Old Woolwich Road',
#       'Greenwich',
#       'Greater London',
#       'SE10 9AS',
#       'United Kingdom']},
#     'categories': [{'id': '5032891291d4c4b30a586d68',
#       'name': 'Assisted Living',
#       'pluralName': 'Assisted Living',
#       'shortName': 'Assisted Living',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ac518d1f964a520cda620e3',
#     'name': 'Royal Hospital Chelsea',
#     'location': {'address': 'Royal Hospital Rd.',
#      'lat': 51.48791804199486,
#      'lng': -0.15681004413047214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48791804199486,
#        'lng': -0.15681004413047214}],
#      'distance': 19835,
#      'postalCode': 'SW3 4SR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Royal Hospital Rd.',
#       'London',
#       'Greater London',
#       'SW3 4SR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '5757c694cd10b03414af2a35',
#     'name': "Ophthalmology Department, Queen Mary's Hospital",
#     'location': {'address': "B Block Level 2, Queen Mary's Hospital",
#      'crossStreet': 'Frognal Ave.',
#      'lat': 51.419632,
#      'lng': 0.10202821,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.419632,
#        'lng': 0.10202821}],
#      'distance': 9931,
#      'postalCode': 'DA14 6LT',
#      'cc': 'GB',
#      'neighborhood': 'Bexley',
#      'country': 'United Kingdom',
#      'formattedAddress': ["B Block Level 2, Queen Mary's Hospital (Frognal Ave.)",
#       'DA14 6LT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b4edb89f964a5206ff626e3',
#     'name': "St. Mary's Hospital",
#     'location': {'address': 'Praed St',
#      'lat': 51.51701684021448,
#      'lng': -0.17466118211771173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51701684021448,
#        'lng': -0.17466118211771173}],
#      'distance': 20974,
#      'postalCode': 'W2 1NY',
#      'cc': 'GB',
#      'city': 'Paddington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Praed St',
#       'Paddington',
#       'Greater London',
#       'W2 1NY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b5705cbf964a5203f2328e3',
#     'name': 'Great Ormond Street Hospital For Children',
#     'location': {'address': 'Great Ormond St',
#      'lat': 51.52200047198426,
#      'lng': -0.12052583565917294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52200047198426,
#        'lng': -0.12052583565917294}],
#      'distance': 17272,
#      'postalCode': 'WC1N 1EH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Great Ormond St',
#       'London',
#       'Greater London',
#       'WC1N 1EH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ad30f19f964a52006e320e3',
#     'name': 'Kingston Hospital',
#     'location': {'address': 'Galsworthy Rd',
#      'lat': 51.414758977004226,
#      'lng': -0.2817821502685547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.414758977004226,
#        'lng': -0.2817821502685547}],
#      'distance': 30214,
#      'postalCode': 'KT2 7QB',
#      'cc': 'GB',
#      'city': 'Kingston',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Galsworthy Rd',
#       'Kingston',
#       'Greater London',
#       'KT2 7QB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b6697c8f964a520f9242be3',
#     'name': 'PDSA Pet Aid Hospital - Bow',
#     'location': {'address': 'Malmesbury Road',
#      'lat': 51.529684775421416,
#      'lng': -0.023941854211160594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.529684775421416,
#        'lng': -0.023941854211160594}],
#      'distance': 10793,
#      'postalCode': 'E3 2DT',
#      'cc': 'GB',
#      'city': 'Poplar',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Malmesbury Road',
#       'Poplar',
#       'Greater London',
#       'E3 2DT',
#       'United Kingdom']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b881ffcf964a52081e131e3',
#     'name': 'BMI The Sloane Hospital',
#     'location': {'address': '125 Albemarle Rd',
#      'lat': 51.408144107084134,
#      'lng': -0.004768967628479004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.408144107084134,
#        'lng': -0.004768967628479004}],
#      'distance': 14370,
#      'postalCode': 'BR3 5HS',
#      'cc': 'GB',
#      'city': 'Beckenham',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['125 Albemarle Rd',
#       'Beckenham',
#       'Greater London',
#       'BR3 5HS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b48f1aff964a520ad5e26e3',
#     'name': 'Maudsley Hospital',
#     'location': {'address': 'Denmark Hill',
#      'lat': 51.469160429066164,
#      'lng': -0.09149232207092034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.469160429066164,
#        'lng': -0.09149232207092034}],
#      'distance': 15778,
#      'postalCode': 'SE5 8AZ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Denmark Hill',
#       'London',
#       'Greater London',
#       'SE5 8AZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4f8d1110e4b0224490d22daa',
#     'name': 'In house Hospital free taxi telephone service',
#     'location': {'lat': 51.549024276916114,
#      'lng': -0.04190621428224668,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.549024276916114,
#        'lng': -0.04190621428224668}],
#      'distance': 12626,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b75862cf964a52094112ee3',
#     'name': 'The Lister Hospital',
#     'location': {'address': 'Chelsea Bridge Rd.',
#      'lat': 51.48635073190487,
#      'lng': -0.15035232312606248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48635073190487,
#        'lng': -0.15035232312606248}],
#      'distance': 19411,
#      'postalCode': 'SW1W 8RH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Chelsea Bridge Rd.',
#       'London',
#       'Greater London',
#       'SW1W 8RH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b057699f964a520805822e3',
#     'name': "Evelina London Children's Hospital",
#     'location': {'address': "St Thomas' Hospital, Westminster Bridge Rd",
#      'lat': 51.499772798382324,
#      'lng': -0.11881409222099718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.499772798382324,
#        'lng': -0.11881409222099718}],
#      'distance': 17102,
#      'postalCode': 'SE1 7EH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["St Thomas' Hospital, Westminster Bridge Rd",
#       'London',
#       'Greater London',
#       'SE1 7EH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ad58e94f964a520230321e3',
#     'name': 'Royal Free Hospital',
#     'location': {'address': '10 Pond St',
#      'lat': 51.553713786156635,
#      'lng': -0.1660911811696297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.553713786156635,
#        'lng': -0.1660911811696297}],
#      'distance': 20988,
#      'postalCode': 'NW3 2QG',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Pond St',
#       'London',
#       'Greater London',
#       'NW3 2QG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4ba49beff964a5202ca738e3',
#     'name': 'Orsett Hospital',
#     'location': {'address': 'Rowley Rd.',
#      'lat': 51.50957022054918,
#      'lng': 0.36598768320856895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50957022054918,
#        'lng': 0.36598768320856895}],
#      'distance': 16511,
#      'postalCode': 'RM16 3EU',
#      'cc': 'GB',
#      'city': 'Orsett',
#      'state': 'Essex',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rowley Rd.',
#       'Orsett',
#       'Essex',
#       'RM16 3EU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bae1408f964a520a6813be3',
#     'name': 'Croydon University Hospital',
#     'location': {'address': '530 London Rd',
#      'lat': 51.38944606418133,
#      'lng': -0.11048569951554318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.38944606418133,
#        'lng': -0.11048569951554318}],
#      'distance': 21106,
#      'postalCode': 'CR7 7YE',
#      'cc': 'GB',
#      'city': 'Thornton Heath',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['530 London Rd',
#       'Thornton Heath',
#       'Greater London',
#       'CR7 7YE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4c03cc47187ec928c017b67b',
#     'name': 'London Chest Hospital',
#     'location': {'address': 'Bonner Rd.',
#      'lat': 51.531869754575176,
#      'lng': -0.04940645866971184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.531869754575176,
#        'lng': -0.04940645866971184}],
#      'distance': 12566,
#      'postalCode': 'E2 9JX',
#      'cc': 'GB',
#      'city': 'Bethnal Green',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Bonner Rd.',
#       'Bethnal Green',
#       'Greater London',
#       'E2 9JX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4b50d026f964a520643327e3',
#     'name': 'Dulwich Community Hospital',
#     'location': {'address': 'E. Dulwich Grove',
#      'lat': 51.45850511887406,
#      'lng': -0.08185895766330585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.45850511887406,
#        'lng': -0.08185895766330585}],
#      'distance': 15513,
#      'postalCode': 'S E22',
#      'cc': 'GB',
#      'city': 'East Dulwich',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['E. Dulwich Grove',
#       'East Dulwich',
#       'Greater London',
#       'S E22',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '4bbb14251261d13a523beb98',
#     'name': 'Royal Brompton Hospital',
#     'location': {'address': 'Sydney St',
#      'lat': 51.48915172189793,
#      'lng': -0.17015513606314195,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48915172189793,
#        'lng': -0.17015513606314195}],
#      'distance': 20741,
#      'postalCode': 'SW3 6LL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Sydney St',
#       'London',
#       'Greater London',
#       'SW3 6LL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False},
#    {'id': '509a9bb4e4b02754b6712308',
#     'name': 'Bus Stop D @ Homerton Hospital',
#     'location': {'lat': 51.54967467394348,
#      'lng': -0.045919170007340006,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.54967467394348,
#        'lng': -0.045919170007340006}],
#      'distance': 12911,
#      'postalCode': 'E9',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London', 'Greater London', 'E9', 'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606981230',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                      name  \
# 0  4b4e1c8af964a5209ce126e3            Guy's Hospital
# 1  4bfe353af7c82d7f8a438f04  Queen Elizabeth Hospital
# 2  4bf3a32b706e20a1976ca898   King's College Hospital
# 3  4ac518f6f964a5205eaf20e3       St Thomas' Hospital
# 4  4be47840910020a1e0c2d114     Queen Mary's Hospital
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1606981230    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1606981230    False
# 2  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1606981230    False
# 3  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1606981230    False
# 4  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1606981230    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0        Great Maze Pond        St. Thomas St     51.503526     -0.086732
# 1            Stadium Rd.                  NaN     51.478861      0.050717
# 2           Denmark Hill                  NaN     51.468150     -0.093016
# 3  Westminster Bridge Rd                  NaN     51.499710     -0.118904
# 4            Frognal Ave                  NaN     51.419561      0.101549
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.50352551239466...              14864
# 1  [{'label': 'display', 'lat': 51.47886089765733...               6209
# 2  [{'label': 'display', 'lat': 51.46814989580254...              15910
# 3  [{'label': 'display', 'lat': 51.49971047720161...              17109
# 4  [{'label': 'display', 'lat': 51.41956136232628...               9944
#
#   location.postalCode location.cc location.city  location.state  \
# 0             SE1 9RT          GB        London  Greater London
# 1            SE18 4QH          GB     Greenwich  Greater London
# 2             SE5 9RS          GB    Camberwell  Greater London
# 3             SE1 7EH          GB        London  Greater London
# 4            DA14 6LT          GB        Sidcup  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [Great Maze Pond (St. Thomas St), London, Grea...
# 1   United Kingdom  [Stadium Rd., Greenwich, Greater London, SE18 ...
# 2   United Kingdom  [Denmark Hill, Camberwell, Greater London, SE5...
# 3   United Kingdom  [Westminster Bridge Rd, London, Greater London...
# 4   United Kingdom  [Frognal Ave, Sidcup, Greater London, DA14 6LT...
#
#   venuePage.id           location.neighborhood
# 0          NaN                             NaN
# 1          NaN                             NaN
# 2    600424239                             NaN
# 3          NaN                             NaN
# 4          NaN  Sidcup, London, Greater London

# %%
hospital_df = dataframe[['name', 'location.lat', 'location.lng', 'location.city' ]]

# %%
hospital_df = hospital_df.rename(columns={'name':'Name','location.lat':'Lat', 'location.lng':'Lon', 'location.city':'City'})

# %%
hospital_df = hospital_df.loc[hospital_df['City']=='London']

# %%
hospital_df.head()
# Out:
#                                       Name        Lat       Lon    City
# 0                           Guy's Hospital  51.503526 -0.086732  London
# 3                      St Thomas' Hospital  51.499710 -0.118904  London
# 7                St Bartholomew's Hospital  51.517863 -0.099607  London
# 9   The Hospital of St John & St Elizabeth  51.532949 -0.174645  London
# 13            Homerton University Hospital  51.550134 -0.045918  London

# %%
hospital_df.shape
# Out:
# (21, 4)

# %%
m = folium.Map(tiles = 'Stamen Terrain' ,location=[latitude, longitude], zoom_start = 11)

for lat, lng in zip(hospital_df.Lat, hospital_df.Lon):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(m)
m

# %% [markdown]
# # Shape File of London

# %%
gdf = gpd.read_file(r'C:\Users\J.D\Desktop\Project\statistical-gis-boundaries-london\statistical-gis-boundaries-london\ESRI\London_Borough_Excluding_MHW.shp')

# %%
gdf = gdf [['NAME', 'HECTARES','geometry']]

# %%
gdf.rename(columns={'NAME':'Name', 'HECTARES':'Area'}, inplace=True)

# %%
gdf.head()
# Out:
#                    Name       Area  \
# 0  Kingston upon Thames   3726.117
# 1               Croydon   8649.441
# 2               Bromley  15013.487
# 3              Hounslow   5658.541
# 4                Ealing   5554.428
#
#                                             geometry
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4  POLYGON ((510253.500 182881.600, 510249.900 18...

# %% [markdown]
# # Getting population data

# %%
url = 'https://www.citypopulation.de/en/uk/greaterlondon/'
parts = requests.get(url).content
df_html = pd.read_html(parts)

# %%
pop_df = df_html[0]

# %%
pop_df.head()
# Out:
#                    Name   Status  PopulationEstimate1981-06-30  \
# 0  Barking and Dagenham  Borough                        161300
# 1                Barnet  Borough                        295200
# 2                Bexley  Borough                        217400
# 3                 Brent  Borough                        248300
# 4               Bromley  Borough                        299200
#
#    PopulationEstimate1991-06-30  PopulationEstimate2001-06-30  \
# 0                        155500                        165700
# 1                        297700                        319500
# 2                        218100                        218800
# 3                        240800                        269600
# 4                        293500                        296200
#
#    PopulationEstimate2011-06-30  PopulationEstimate2019-06-30 Unnamed: 7
# 0                        187029                        212906          →
# 1                        357538                        395869          →
# 2                        232774                        248287          →
# 3                        312245                        329771          →
# 4                        310554                        332336          →

# %%
pop_df = pop_df[['Name', 'PopulationEstimate2019-06-30']]

# %%
pop_df = pop_df.rename(columns={'PopulationEstimate2019-06-30':'Population'})

# %%
print('The number of boroughs in population dataset is ',pop_df.shape)
print('The number of boroughs in shape file is ', gdf.shape)
# Out:
# The number of boroughs in population dataset is  (34, 2)
# The number of boroughs in shape file is  (33, 3)

# %%
for index,row in pop_df['Name'].iteritems():
    if row in gdf['Name'].tolist():
        pass
    else:
        print('This borough is not in the list '+row)
# Out:
# This borough is not in the list City of Westminster
# This borough is not in the list Greater London

# %%
pop_df.at[7, 'Name'] = 'Westminster'

# %%
pop_df.drop(pop_df.index[33], inplace=True)

# %%
gdf['Area'] = gdf['Area']/100

# %%
gdf = gdf.merge(right=pop_df, on='Name')

# %%
gdf['Pop_Density'] = gdf['Population']/gdf['Area']

# %%
gdf.head()
# Out:
#                    Name       Area  \
# 0  Kingston upon Thames   37.26117
# 1               Croydon   86.49441
# 2               Bromley  150.13487
# 3              Hounslow   56.58541
# 4                Ealing   55.54428
#
#                                             geometry  Population  Pop_Density
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...      177507  4763.860072
# 1  POLYGON ((535009.200 159504.700, 535005.500 15...      386710  4470.924768
# 2  POLYGON ((540373.600 157530.400, 540361.200 15...      332336  2213.583027
# 3  POLYGON ((521975.800 178100.000, 521967.700 17...      271523  4798.463067
# 4  POLYGON ((510253.500 182881.600, 510249.900 18...      341806  6153.756967

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf.plot(column='Pop_Density', figsize=(10,12), cmap='Spectral', legend=True)

m = folium.Map(tiles = 'Stamen Terrain' ,location=[latitude, longitude], zoom_start = 11,
              width=800, height=500)

for lat, lng in zip(hospital_df.Lat, hospital_df.Lon):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
